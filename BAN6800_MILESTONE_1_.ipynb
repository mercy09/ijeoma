# %% [markdown]
# <a href="https://colab.research.google.com/github/mercy09/ijeoma/blob/main/BAN6800_MILESTONE_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# LOADING AND INTEGRATING DATA

# %%
# Load datasets
orders = pd.read_csv('/content/olist_orders_dataset.csv')
customers = pd.read_csv('/content/olist_customers_dataset.csv')
order_items = pd.read_csv('/content/olist_order_items_dataset.csv')
products = pd.read_csv('/content/olist_products_dataset.csv')
payments = pd.read_csv('/content/olist_order_payments_dataset.csv')
reviews = pd.read_csv('/content/olist_order_reviews_dataset.csv')

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered         02/10/2017 10:56  02/10/2017 11:07
# 1    delivered         24/07/2018 20:41  26/07/2018 03:24
# 2    delivered         08/08/2018 08:38  08/08/2018 08:55
# 3    delivered         18/11/2017 19:28  18/11/2017 19:45
# 4    delivered         13/02/2018 21:18  13/02/2018 22:20
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0             04/10/2017 19:55              10/10/2017 21:25
# 1             26/07/2018 14:31              07/08/2018 15:27
# ...

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
# Merge orders with customers
orders_customers = pd.merge(orders, customers, on='customer_id',  how='inner')

# Merge with order items
order_full = pd.merge(orders_customers, order_items, on='order_id', how='inner')

# Merge with product data
order_full = pd.merge(order_full, products, on='product_id', how='left')

# Merge with payment info
order_full = pd.merge(order_full, payments, on='order_id', how='left')

# %%
order_full.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered         02/10/2017 10:56  02/10/2017 11:07
# 1    delivered         02/10/2017 10:56  02/10/2017 11:07
# 2    delivered         02/10/2017 10:56  02/10/2017 11:07
# 3    delivered         24/07/2018 20:41  26/07/2018 03:24
# 4    delivered         08/08/2018 08:38  08/08/2018 08:55
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0             04/10/2017 19:55              10/10/2017 21:25
# 1             04/10/2017 19:55              10/10/2017 21:25
# ...

# %%
order_full.shape
# Out:
# (117604, 32)

# %%
order_full.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'customer_city_x', 'customer_state_x', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city_y', 'customer_state_y',
#        'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date',
#        'price', 'freight_value', 'product_category_name',
#        'product_name_lenght', 'product_description_lenght',
#        'product_photos_qty', 'product_weight_g', 'product_length_cm',
#        'product_height_cm', 'product_width_cm', 'payment_sequential',
#        'payment_type', 'payment_installments', 'payment_value'],
#       dtype='object')

# %%
order_full.columns.shape
# Out:
# (32,)

# %%
order_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117604 entries, 0 to 117603
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       117604 non-null  object
#  1   customer_id                    117604 non-null  object
#  2   order_status                   117604 non-null  object
#  3   order_purchase_timestamp       117604 non-null  object
#  4   order_approved_at              117589 non-null  object
#  5   order_delivered_carrier_date   116359 non-null  object
#  6   order_delivered_customer_date  115037 non-null  object
#  7   order_estimated_delivery_date  117604 non-null  object
#  8   customer_city_x                117604 non-null  object
#  9   customer_state_x               117604 non-null  object
#  10  customer_unique_id             117604 non-null  object
#  11  customer_zip_code_prefix       117604 non-null  int64
# ...

# %%
order_full.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'customer_city_x', 'customer_state_x', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city_y', 'customer_state_y',
#        'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date',
#        'price', 'freight_value', 'product_category_name',
#        'product_name_lenght', 'product_description_lenght',
#        'product_photos_qty', 'product_weight_g', 'product_length_cm',
#        'product_height_cm', 'product_width_cm', 'payment_sequential',
#        'payment_type', 'payment_installments', 'payment_value'],
#       dtype='object')

# %%
order_full.describe()
# Out:
#        customer_zip_code_prefix  order_item_id          price  freight_value  \
# count             117604.000000  117604.000000  117604.000000  117604.000000
# mean               35051.271385       1.195920     120.822849      20.045551
# std                29820.387420       0.697721     184.477367      15.861351
# min                 1003.000000       1.000000       0.850000       0.000000
# 25%                11310.000000       1.000000      39.900000      13.080000
# 50%                24315.000000       1.000000      74.900000      16.290000
# 75%                58600.000000       1.000000     134.900000      21.190000
# max                99990.000000      21.000000    6735.000000     409.680000
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count        115906.000000               115906.000000       115906.000000
# mean             48.767208                  786.957302            2.207849
# ...

# %% [markdown]
#  STEP 2: CLEAN & PREPROCESSING DATA

# %%
# Check missing and null values
missing = order_full.isnull().sum()
print(missing[missing > 0])
# Out:
# order_approved_at                  15
# order_delivered_carrier_date     1245
# order_delivered_customer_date    2567
# product_category_name            1698
# product_name_lenght              1698
# product_description_lenght       1698
# product_photos_qty               1698
# product_weight_g                   20
# product_length_cm                  20
# product_height_cm                  20
# product_width_cm                   20
# payment_sequential                  3
# payment_type                        3
# payment_installments                3
# payment_value                       3
# dtype: int64

# %%
order_full = order_full.dropna()

# %%
order_full.isnull().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# customer_city_x                  0
# customer_state_x                 0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city_y                  0
# customer_state_y                 0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# product_category_name            0
# product_name_lenght              0
# product_description_lenght       0
# product_photos_qty               0
# product_weight_g                 0
# product_length_cm                0
# product_height_cm                0
# ...

# %%
# Check total number of duplicate rows
duplicate_rows = order_full[order_full.duplicated()]
print("Number of duplicate rows:", duplicate_rows.shape[0])
# Out:
# Number of duplicate rows: 0

# %%
# Convert dates
date_cols = ['order_purchase_timestamp', 'order_approved_at',
             'order_delivered_carrier_date', 'order_delivered_customer_date',
             'order_estimated_delivery_date']

for col in date_cols:
    order_full[col] = pd.to_datetime(order_full[col], format='%d/%m/%Y %H:%M')

# %%
order_full
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 117599  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 117600  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 117601  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 117602  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 117603  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
#Drop Irrelevant Colunms
order_full = order_full.drop(['order_approved_at','product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm','product_photos_qty'], axis=1)

# %% [markdown]
# STEP 3: TRANSFORMATION & FEATURE ENGINEERING

# %%
#Delivery Time (actual vs estimated)
order_full['delivery_delay'] = (order_full['order_estimated_delivery_date'] - order_full['order_delivered_customer_date']).dt.days
order_full['actual_delivery_time'] = (order_full['order_delivered_customer_date'] - order_full['order_purchase_timestamp']).dt.days

# %%
#Price-related Features
# Total order price per product
order_full['order_item_total'] = order_full['price'] + order_full['freight_value']

# %%
#Order Count Per Customer
order_count = order_full.groupby('customer_id')['order_id'].nunique().reset_index()
order_count.columns = ['customer_id', 'total_orders']
order_full = pd.merge(order_full, order_count, on='customer_id', how='left')

# %%
#Monetary Value Per Customer (Total Spend)
customer_spend = order_full.groupby('customer_id')['order_item_total'].sum().reset_index()
customer_spend.columns = ['customer_id', 'total_spent']
order_full = pd.merge(order_full, customer_spend, on='customer_id', how='left')

# %%
#Recency Feature
import datetime
reference_date = order_full['order_purchase_timestamp'].max()
recency_df = order_full.groupby('customer_id')['order_purchase_timestamp'].max().reset_index()
recency_df['recency_days'] = (reference_date - recency_df['order_purchase_timestamp']).dt.days
order_full = pd.merge(order_full, recency_df[['customer_id', 'recency_days']], on='customer_id', how='left')

# %%
#frequency
frequency_df = order_full.groupby('customer_id')['order_id'].count().reset_index()
frequency_df.columns = ['customer_id', 'frequency']
order_full = pd.merge(order_full, frequency_df, on='customer_id', how='left')

# %%
order_full
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 113385  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 113386  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 113387  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113388  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113389  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %%
# Save cleaned data to a new CSV file
order_full.to_csv('amazon_data_cleaned.csv', index=False)

# %% [markdown]
# RECREATING NEW AND IMPORTANT COLUMNS FOR SEGMENTATION ANALYSIS

# %%
order_full = order_full[['customer_id','total_orders', 'total_spent','recency_days','frequency', 'actual_delivery_time','delivery_delay','product_category_name','payment_type']].copy()
order_full
# Out:
#                              customer_id  total_orders  total_spent  \
# 0       9ef432eb6251297304e76186b10a928d             1       116.13
# 1       9ef432eb6251297304e76186b10a928d             1       116.13
# 2       9ef432eb6251297304e76186b10a928d             1       116.13
# 3       b0830fb4747a6c6d20dea0b8c802d7ef             1       141.46
# 4       41ce2a54c0b03bf3443c3d931a367089             1       179.12
# ...                                  ...           ...          ...
# 113385  1fca14ff2861355f6e5f14306ff977a7             1       195.00
# 113386  1aa71eb042121263aafbe80c1b562c9c             1       271.01
# 113387  b331b74b18dc79bcdf6532d51e1637c1             1       441.16
# 113388  b331b74b18dc79bcdf6532d51e1637c1             1       441.16
# 113389  edb027a75a1449115f6b43211ae02a24             1        86.86
#
#         recency_days  frequency  actual_delivery_time  delivery_delay  \
# 0                331          3                     8               7
# ...
