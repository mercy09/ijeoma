# %% [markdown]
# <a href="https://colab.research.google.com/github/mercy09/ijeoma/blob/main/NAIVE%20BAYES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/Titanic-Dataset.csv')
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df.drop(['PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked'],axis = 'columns', inplace =True)
df.head(20)
# Out:
#     Survived  Pclass     Sex   Age     Fare
# 0          0       3    male  22.0   7.2500
# 1          1       1  female  38.0  71.2833
# 2          1       3  female  26.0   7.9250
# 3          1       1  female  35.0  53.1000
# 4          0       3    male  35.0   8.0500
# 5          0       3    male   NaN   8.4583
# 6          0       1    male  54.0  51.8625
# 7          0       3    male   2.0  21.0750
# 8          1       3  female  27.0  11.1333
# 9          1       2  female  14.0  30.0708
# 10         1       3  female   4.0  16.7000
# 11         1       1  female  58.0  26.5500
# 12         0       3    male  20.0   8.0500
# 13         0       3    male  39.0  31.2750
# 14         0       3  female  14.0   7.8542
# 15         1       2  female  55.0  16.0000
# 16         0       3    male   2.0  29.1250
# 17         1       2    male   NaN  13.0000
# 18         0       3  female  31.0  18.0000
# 19         1       3  female   NaN   7.2250

# %%
target = df.Survived
inputs = df.drop('Survived', axis= 'columns')
inputs.head()
# Out:
#    Pclass     Sex   Age     Fare
# 0       3    male  22.0   7.2500
# 1       1  female  38.0  71.2833
# 2       3  female  26.0   7.9250
# 3       1  female  35.0  53.1000
# 4       3    male  35.0   8.0500

# %%
dummies = pd.get_dummies(inputs.Sex)
dummies.head(3)
# Out:
#    female   male
# 0   False   True
# 1    True  False
# 2    True  False

# %%
# Convert True → 0 and False → 1
dummies = (dummies).astype(int)
dummies.head(3)
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0

# %%
input = pd.concat([inputs, dummies], axis = 1)
input.head()
# Out:
#    Pclass     Sex   Age     Fare  female  male
# 0       3    male  22.0   7.2500       0     1
# 1       1  female  38.0  71.2833       1     0
# 2       3  female  26.0   7.9250       1     0
# 3       1  female  35.0  53.1000       1     0
# 4       3    male  35.0   8.0500       0     1

# %%
input.drop('Sex', axis = 1, inplace = True)
input.head(5)
# Out:
#    Pclass   Age     Fare  female  male
# 0       3  22.0   7.2500       0     1
# 1       1  38.0  71.2833       1     0
# 2       3  26.0   7.9250       1     0
# 3       1  35.0  53.1000       1     0
# 4       3  35.0   8.0500       0     1

# %%
input.columns[input.isna().any()]
# Out:
# Index(['Age'], dtype='object')

# %%
input.Age[:10]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %%
input.Age = input.Age.fillna(input.Age.mean())
input.head(6)
# Out:
#    Pclass        Age     Fare  female  male
# 0       3  22.000000   7.2500       0     1
# 1       1  38.000000  71.2833       1     0
# 2       3  26.000000   7.9250       1     0
# 3       1  35.000000  53.1000       1     0
# 4       3  35.000000   8.0500       0     1
# 5       3  29.699118   8.4583       0     1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(input, target,test_size = 0.2)

# %%
len(X_train)
# Out:
# 712

# %%
len(X_test)
# Out:
# 179

# %%
len(inputs)
# Out:
# 891

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test, y_test)
# Out:
# 0.776536312849162

# %%
X_test[:10]
# Out:
#      Pclass        Age     Fare  female  male
# 458       2  50.000000  10.5000       1     0
# 811       3  39.000000  24.1500       0     1
# 727       3  29.699118   7.7375       1     0
# 239       2  33.000000  12.2750       0     1
# 365       3  30.000000   7.2500       0     1
# 753       3  23.000000   7.8958       0     1
# 559       3  36.000000  17.4000       1     0
# 406       3  51.000000   7.7500       0     1
# 524       3  29.699118   7.2292       0     1
# 650       3  29.699118   7.8958       0     1

# %%
y_test[:10]
# Out:
# 458    1
# 811    0
# 727    1
# 239    0
# 365    0
# 753    0
# 559    1
# 406    0
# 524    0
# 650    0
# Name: Survived, dtype: int64

# %%
model.predict(X_test[:10])
# Out:
# array([1, 0, 1, 0, 0, 0, 1, 0, 0, 0])

# %%
model.predict_proba(X_test[:10])
# Out:
# array([[0.02828456, 0.97171544],
#        [0.99095568, 0.00904432],
#        [0.05839324, 0.94160676],
#        [0.98146438, 0.01853562],
#        [0.99051113, 0.00948887],
#        [0.98963638, 0.01036362],
#        [0.06246138, 0.93753862],
#        [0.98996833, 0.01003167],
#        [0.99048247, 0.00951753],
#        [0.99053232, 0.00946768]])
